# %%
import numpy as np
import pandas as pd

#set cd to data folder with QC'ed rides
% cd /Users/fineiskid/Desktop/Access_Analysis_Rproject_local/data/
# Out:
# /Users/fineiskid/Desktop/Access_Analysis_Rproject_local/data

# %%
rides = pd.read_csv("UW_Trip_Data_QC.csv")

# %%
rides.head(30)
# Out:
#     Unnamed: 0  Rownum ServiceDate   Run  ProviderId   EvOrder   EvId  \
# 0            1      61  0015-01-01  9701           6         1   1195
# 1            2      62  0015-01-01  9701           6   3225836   6878
# 2            3      63  0015-01-01  9701           6   5815993   6879
# 3            4      64  0015-01-01  9701           6   9677402   8711
# 4            5      65  0015-01-01  9701           6  12903201   8749
# 5            6      66  0015-01-01  9701           6  18750022   8663
# 6            7      67  0015-01-01  9701           6  20413334   8605
# 7            8      68  0015-01-01  9701           6  20967741   7982
# 8            9      69  0015-01-01  9701           6  31187536   7983
# 9           10      70  0015-01-01  9701           6  35881498   1756
# 10          11      71  0015-01-01  9701           6  40213966   9384
# 11          12      72  0015-01-01  9701           6  41658084   1757
# ...

# %%
testdates = pd.to_datetime(rides["ServiceDate"].head(), format ='%Y-%m-%d', unit = "D")
type(testdates[1])
# Out:
# str

# %%
rides["ServiceDate"] = pd.to_datetime(rides["ServiceDate"], format ='%Y-%m-%d', unit = "D")
dates = rides["ServiceDate"].unique()
dates
# Out:
# array(['0015-01-01', '0015-01-03', '0015-01-04', '0015-01-10',
#        '0015-01-11', '0015-01-17', '0015-01-18', '0015-01-24',
#        '0015-01-25', '0015-01-31', '0015-02-01', '0015-02-07',
#        '0015-02-08', '0015-02-14', '0015-02-15', '0015-02-21',
#        '0015-02-22', '0015-02-28', '0015-03-01', '0015-03-07',
#        '0015-03-08', '0015-03-14', '0015-03-15', '0015-03-21',
#        '0015-03-22', '0015-03-28', '0015-03-29', '0015-04-04',
#        '0015-04-05', '0015-04-11', '0015-04-12', '0015-04-18',
#        '0015-04-19', '0015-04-25', '0015-04-26', '0015-01-07',
#        '0015-01-09', '0015-01-12', '0015-01-13', '0015-01-14',
#        '0015-01-15', '0015-01-16', '0015-01-21', '0015-01-22',
#        '0015-01-23', '0015-01-28', '0015-01-29', '0015-01-30',
#        '0015-02-02', '0015-02-04', '0015-02-05', '0015-02-11',
#        '0015-02-12', '0015-02-13', '0015-02-18', '0015-02-20',
#        '0015-02-25', '0015-02-26', '0015-02-27', '0015-03-03',
# ...

# %%
Apr_4 = rides[rides["ServiceDate"] == "0015-04-04"] #all rides on April 4, 2015
Apr_4.shape
# Out:
# (2922, 25)

# %%
len(Apr_4["Run"].unique()) #number of runs on April 4, 2015
import time
breakdown = time.strptime("13:30:04", "%H:%M:%S")
breakdownETA = breakdown.tm_hour*60 + breakdown.tm_min + breakdown.tm_sec/60.0
breakdownETA
# Out:
# 810.0666666666667

# %%
newETA = Apr_4["ETA"]/60
newETA.head()
print("breakdown time is %f mins" % breakdownETA)
breakdownride = Apr_4["Run"].unique()[14] #set breakdown ride
print("breakdown ride is Run %s "%breakdownride)
# Out:
# breakdown time is 810.066667 mins
# breakdown ride is Run 9016

# %%
leftover = Apr_4[Apr_4["ETA"]/60 >= breakdownETA]

# %%
len(leftover["Run"].unique())
# Out:
# 107

# %%
len(Apr_4["Run"].unique())
# Out:
# 117

# %%
pickmeup = leftover[leftover["Run"]==breakdownride]

# %%
pickmeup
# Out:
#         Unnamed: 0  Rownum ServiceDate   Run  ProviderId   EvOrder   EvId  \
# 499781      499782  622882  0015-04-04  9016           6  83401301   6170
# 499782      499783  622883  0015-04-04  9016           6  85354514   4002
# 499783      499784  622884  0015-04-04  9016           6  85585985   3361
# 499784      499785  622885  0015-04-04  9016           6  86280478   3954
# 499785      499786  622886  0015-04-04  9016           6  88363835   6229
# 499786      499787  622887  0015-04-04  9016           6  91100809   5414
# 499787      499788  622888  0015-04-04  9016           6  97775187  16223
# 499788      499789  622889  0015-04-04  9016           6  99999998    288
#
#         Activity    ETA  DwellTime    ...      BookingId SchedStatus  \
# 499781         0  50258        420    ...       19433145           1
# 499782         0  50875        180    ...       19427450           1
# 499783         1  52948        120    ...       19424004           1
# ...

# %%
clients = pickmeup["ClientID"].unique()
clients = clients[~np.isnan(clients)]
clients
for cli in clients:
    onoff = pickmeup[pickmeup["ClientID"]==cli]
    if onoff.shape[0] == 1:
        print(onoff.ClientID)
        unschedBag = pickmeup[pickmeup["ClientID"] != cli]
# Out:
# 499783    7300
# Name: ClientID, dtype: float64

# %%
unschedBag = unschedBag[unschedBag["Activity"] != 6]
unschedBag = unschedBag[unschedBag["Activity"] != 16]
unschedBag = unschedBag[unschedBag["Activity"] != 3]

# %%
unschedBag #people who were originally planned to be picked up and dropped off on broken bus after bus has broken
# Out:
#         Unnamed: 0  Rownum ServiceDate   Run  ProviderId   EvOrder  EvId  \
# 499781      499782  622882  0015-04-04  9016           6  83401301  6170
# 499782      499783  622883  0015-04-04  9016           6  85354514  4002
# 499784      499785  622885  0015-04-04  9016           6  86280478  3954
# 499785      499786  622886  0015-04-04  9016           6  88363835  6229
#
#         Activity    ETA  DwellTime    ...      BookingId SchedStatus  \
# 499781         0  50258        420    ...       19433145           1
# 499782         0  50875        180    ...       19427450           1
# 499784         1  53714        120    ...       19427450           1
# 499785         1  55920        300    ...       19433145           1
#
#        SubtypeAbbr  FundingsourceId1  PassOn  PassOff  ClientID NumOn  NumOff  \
# 499781         DEM                 1    CLI1      NaN     11525     1       0
# 499782         DEM                 1    CLI1      NaN    100998     1       0
# ...

# %%
#time that first stranded passenger needs to get picked up
m, s = divmod(50258, 60)
h, m = divmod(m, 60)
print "Pick up unschedBag[0] at %d:%02d:%02d" % (h, m, s)
# Out:
# Pick up unschedBag[0] at 13:57:38

# %%
#etas of buses that are between breakdown and first stranded passenger's eta
newETA = newETA[(newETA<=divmod(50258,60)[0]) & (newETA>=breakdownETA)]

# %%
newETA.index
# Out:
# Int64Index([1889, 40792, 42680, 493019, 493625, 494048, 497637, 498107, 499405, 499406, 499407, 500182, 500556, 500557, 500558, 500995, 502149, 502572, 502573, 503380, 503749, 503750, 504178, 504179, 504608, 504996, 504997, 505409, 505410, 505411, 505766, 509271, 509788, 509789, 510192, 510525, 510917, 511259, 511598, 512146, 512592, 512968, 512969, 512970, 515020, 515021, 515211, 515601, 515946, 515947, 515948, 515949, 516796, 516797, 516798, 516799, 516800, 517121, 517370, 518450, 518451, 518452, 518453, 518736, 519013, 519437, 520595, 520596, 522128, 522129, 522130, 522131, 522811, 522812, 523206, 523207, 523538, 523539, 523540, 524318, 524319, 524320, 524723, 525213, 525214, 525215, 525216, 525661, 525662, 526139, 526140, 526455, 526892, 527328, 527765, 528174, 528589, 529411, 529786, 530212, ...], dtype='int64')
