# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
adjusted = pd.read_csv('../data/4mo_deadhead_cost_adjusted_results.csv')

# %%
adjusted
# Out:
#       ServiceDate   Run    CostProxy  PctDeadhead
# 0      0015-01-01  9701  2460.000000     0.372764
# 1      0015-01-01  9706  3218.444444     0.414486
# 2      0015-01-01  9702  3466.666667     0.330865
# 3      0015-01-01  9703  3003.000000     0.199606
# 4      0015-01-01  9704  3843.500000     0.426727
# 5      0015-01-01  9707  2970.300000     0.326196
# 6      0015-01-01  9710  3091.777778     0.237116
# 7      0015-01-01  9709  5820.600000     0.341992
# 8      0015-01-01  9722  4086.428571     0.419332
# 9      0015-01-01  9711  5500.000000     0.586091
# 10     0015-01-01  9712  3334.000000     0.312304
# 11     0015-01-01  9723  3227.222222     0.389878
# 12     0015-01-01  9713  5160.000000     0.568572
# 13     0015-01-01  9714  2765.454545     0.370151
# 14     0015-01-01  9724  3187.555556     0.355828
# 15     0015-01-01  9715  4536.000000     0.342498
# 16     0015-01-01  9717  3600.000000     0.494826
# 17     0015-01-01  9718  3336.777778     0.332390
# 18     0015-01-01  9726  3957.142857     0.330469
# 19     0015-01-01  9719  3200.888889     0.366495
# 20     0015-01-01  9721  2914.200000     0.290577
# 21     0015-01-01  9728  3046.166667     0.371669
# 22     0015-01-01  9729  3120.000000     0.307115
# 23     0015-01-01  9730  3240.833333     0.581589
# 24     0015-01-01  8701  2672.727273     0.256769
# 25     0015-01-01  8717  2618.181818     0.269340
# 26     0015-01-01  8720  3041.900000     0.327427
# 27     0015-01-01  8709  3825.000000     0.362320
# 28     0015-01-01  8704  3303.111111     0.421522
# 29     0015-01-01  8716  3018.800000     0.342388
# ...           ...   ...          ...          ...
# 25165  0015-03-20  5540  2400.000000     0.224678
# 25166  0015-04-03  5540  2880.000000     0.214938
# 25167  0015-04-10  5540  3207.923077     0.239815
# 25168  0015-04-17  5540  3228.000000     0.433271
# 25169  0015-04-24  5540  2348.571429     0.308394
# 25170  0015-03-20  5541  5480.000000     0.474209
# 25171  0015-04-03  5541  4179.500000     0.343223
# 25172  0015-04-10  5541  1994.333333     0.304808
# 25173  0015-04-17  5541  3180.000000     0.356813
# 25174  0015-03-20  5542  3420.000000     0.386901
# 25175  0015-04-03  5542  2890.000000     0.296367
# 25176  0015-04-10  5542  2430.000000     0.426200
# 25177  0015-04-24  5543  2830.000000     0.199823
# 25178  0015-03-21  8049  3693.800000     0.374682
# 25179  0015-03-28  8049  1832.000000     0.257860
# 25180  0015-04-04  8049  2750.000000     0.406485
# 25181  0015-03-21  8050  3647.800000     0.440320
# 25182  0015-03-28  8050  4905.000000     0.330224
# 25183  0015-04-11  8050  3624.000000     0.392826
# 25184  0015-04-25  8050  2850.333333     0.572214
# 25185  0015-03-21  8051  4410.000000     0.558844
# 25186  0015-03-28  8051  3020.000000     0.218764
# 25187  0015-04-04  8051  2834.666667     0.164687
# 25188  0015-04-18  8051  6080.000000     0.489474
# 25189  0015-04-25  8051  2960.000000     0.397241
# 25190  0015-04-04  8052  4500.000000     0.327056
# 25191  0015-04-11  8052  3660.000000     0.343934
# 25192  0015-04-18  8052  4650.000000     0.560376
# 25193  0015-04-04  8048  3514.250000     0.381732
# 25194  0015-04-11  8048  3413.333333     0.408301
#
# [25195 rows x 4 columns]

# %%
len(adjusted[adjusted.CostProxy == 14400])
# Out:
# 19

# %%
data = pd.read_csv('../data/UW_Trip_Data_4mo_QC_capacity.csv')

# %%
run = data[(data.ServiceDate == '0015-04-11') & (data.Run == '932')]

# %%
from legPct import runTime

# %%
runTime(run['ETA'])/sum(run.NumOn)
# Out:
# 6900

# %% [markdown]
# run[['Run','Activity','ETA','City', 'NumOn','NumOff','TotalPass']]
